# %%
# Dependencies and Setup
import pandas as pd
#import numpy as np

# File to Load (Remember to Change These)
csv_path = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data_df = pd.read_csv(csv_path)
#myDataFrame.set_index('column_name')

# %%
# count no. of unique values in SN column

Users = purchase_data_df.SN.nunique()
  
print("Number of unique players:",
      Users)

#Creating a new DataFrame 
total_players_df = pd.DataFrame({"Total Players": Users},
                               index=[0])
total_players_df
# Out:
# Number of unique players: 576
#    Total Players
# 0            576

# %%
#attempt to fix Item ID syntax by renaming the column
purchase_data_renamed_df = purchase_data_df.rename(columns={"Item ID": "Item_Id",
                                                            "Purchase ID": "Purchase_Id"
                                                })
purchase_data_renamed_df
# Out:
#      Purchase_Id             SN  Age  Gender  Item_Id  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
#running to see if it will work with new column name
unique_items = purchase_data_renamed_df.Item_Id.nunique()

print("Number of unique item ids:",
      unique_items)
unique_items_df = pd.DataFrame({"Number of Unique Items": unique_items}, 
                               index=[0])
unique_items_df
# Out:
# Number of unique item ids: 179
#    Number of Unique Items
# 0                     179

# %%
#leaving this here as a reference for fact checking
purchase_data_df.describe()
# Out:
#        Purchase ID         Age     Item ID       Price
# count   780.000000  780.000000  780.000000  780.000000
# mean    389.500000   22.714103   91.755128    3.050987
# std     225.310896    6.659444   52.697702    1.169549
# min       0.000000    7.000000    0.000000    1.000000
# 25%     194.750000   20.000000   47.750000    1.980000
# 50%     389.500000   22.000000   92.000000    3.150000
# 75%     584.250000   25.000000  138.000000    4.080000
# max     779.000000   45.000000  183.000000    4.990000

# %%
#average price
average_price = (purchase_data_renamed_df["Price"].mean())
print(average_price)
# Out:
# 3.050987179487176

# %%
#total purchases
purchase_id = purchase_data_renamed_df.Purchase_Id.count()
print(purchase_id)
# Out:
# 780

# %%
#Total Revenue
total_revenue = purchase_data_renamed_df.Price.sum()
print(total_revenue)
# Out:
# 2379.77

# %%
#New Summary Table
summary_df = pd.DataFrame({"Number of Unique Items": unique_items,
                                      "Average Price": average_price,
                                      "Number of Purchases": purchase_id,
                                      "Total Revenue": total_revenue}, index=[0])
summary_df
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179       3.050987                  780        2379.77

# %%
#now format the average price and total revenue to show as dollars# First convert "average_donation", "goal", and "pledged" columns to float
# Then Format to go to two decimal places, include a dollar sign, and use comma notation
summary_df["Average Price"] = summary_df["Average Price"].astype(float).map("${:,.2f}".format)
summary_df["Total Revenue"] = summary_df["Total Revenue"].astype(float).map("${:,.2f}".format)
#hosted_in_us_df["pledged"] = hosted_in_us_df["pledged"].astype(float).map("${:,.2f}".format)
summary_df.head()
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780     $2,379.77

# %%
#Total Gender Count
total_count= purchase_data_renamed_df.Gender.count()
total_count
# Out:
# 780

# %%
#group by gender
#gender_summary = purchase_data_renamed_df.groupby("Gender")

# %%
#count total gender input
gender_total = gender_summary.nunique()["SN"]
gender_total
# Out:
# Gender
# Female                    81
# Male                     484
# Other / Non-Disclosed     11
# Name: SN, dtype: int64

# %%
# Total count by gender and divivde by total players 
percentage_of_players = gender_total / Users * 100

# %%
#count totals of different genders

# %%
#calculate percentages formula
percentage_of_players = gender_total / total_players * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-410-24ad4aaf32f2> in <module>
#       1 #calculate percentages formula
# ----> 2 percentage_of_players = gender_total / total_players * 100
#
# NameError: name 'total_players' is not defined

# %%
# Create a new column that finds the percent
gender_summary_df = pd.DataFrame({"Total Count" : gender_total,
                                  "Percentage of Players" : percentage_of_players})

# %%
#delete index
#gender_summary_df.index.name = None
gender_summary_df
# Out:
#                        Total Count  Percentage of Players
# Gender
# Female                          81              14.062500
# Male                           484              84.027778
# Other / Non-Disclosed           11               1.909722

# %%
#format percentages
gender_summary_df.style.format({"Percentage of Players":"{:.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_bdc19_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bdc19_level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_bdc19_row0_col0" class="data row0 col0" >81</td>
#                         <td id="T_bdc19_row0_col1" class="data row0 col1" >14.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_bdc19_level0_row1" class="row_heading level0 row1" >Male</th>
#                         <td id="T_bdc19_row1_col0" class="data row1 col0" >484</td>
# ...

# %%
#Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#group by gender
gender_summary = purchase_data_renamed_df.groupby("Gender")

#count total gender input
gender_total = gender_summary.nunique()["SN"]
gender_total

#total purchases
total_purchase_gender = purchase_data_renamed_df.groupby("Gender")["Purchase_Id"].count()
print(total_purchase_gender)

#avg purchase price
average_price_gender = purchase_data_renamed_df.groupby("Gender")["Price"].mean()
print(average_price_gender)

#avg purchase total per person
avg_purchase_total_gender = gender_summary["Price"].sum()
print(avg_purchase_total_gender)

#Average Total Purchase by Person by gender
avg_total_purchase_person_gender = avg_purchase_total_gender/gender_total
print(avg_total_purchase_person_gender)

#avg_purchase_total_person_gender = gender_summary["Price"].mean()
#print(avg_purchase_total_person_gender)

#Create a summary data frame to hold the results
gender_summary1_df = pd.DataFrame({"Purchase Count": total_purchase_gender,
                                      "Average Purchase Price": average_price_gender,
                                      "Total Purchase Value": avg_purchase_total_gender,
                                      "Average Total Purchase per Person": avg_total_purchase_person_gender})
gender_summary1_df
#Optional: give the displayed data cleaner formatting
gender_summary1_df.style.format({"Average Purchase Price":"${:.2f}"})
gender_summary1_df.style.format({"Total Purchase Value":"${:.2f}"})
gender_summary1_df.style.format({"Average Total Purchase per Person":"${:.2f}"})
#summary_df["Average Price"].astype(float).map("${:,.2f}".format)
#Display the summary data frame
gender_summary1_df
# Out:
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15
# Name: Purchase_Id, dtype: int64
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64
# Gender
# Female                   4.468395
# Male                     4.065372
# Other / Non-Disclosed    4.562727
# dtype: float64
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Total Purchase Value  Average Total Purchase per Person
# Gender
# ...

# %%
#checking ages, was showing all <10, ran from the top and now it's fine
purchase_data_renamed_df
# Out:
#      Purchase_Id             SN  Age  Gender  Item_Id  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
#Age Demographics
 
#Establish bins for ages
age_max = purchase_data_renamed_df["Age"].max()
print(age_max)
age_min = purchase_data_renamed_df["Age"].min()
print(age_min)

# Create the bins in which Data will be held   
bins = [0, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 100]

# Create the names for the bins
bin_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

#Categorize the existing players using the age bins. Hint: use pd.cut()
purchase_data_renamed_df["Age Bins"] = pd.cut(purchase_data_renamed_df["Age"], bins, labels=bin_names, include_lowest=True)
purchase_data_renamed_df

# Creating a group based off of the bins - function after groupby
#age_bins = purchase_data_renamed_df.groupby("Age Bins")
#age_bins.min()

#take out duplicate players 
total_age_count = age_bins_df.nunique()["SN"]
total_age_count
#print(age_bins_df["SN"].count())
#Users = purchase_data_df.SN.nunique()

# Get the percentage 
#age_bins[["comments", "duration", "languages"]].mean()
age_percent = total_age_count/Users *100
age_percent

#Create a summary data frame to hold the results
age_summary_df = pd.DataFrame({"Total Count": total_age_count,
                            "Percentage of Players": age_percent})                         
age_summary_df

#Optional: round the percentage column to two decimal points
age_summary_df.style.format({"Percentage of Players":"{:.2f}%"})

#Display Age Demographics Table
#print(np.dtype(np.summary_ages_df))

#imported numpy, found this code to make it work?
#print(np.dtype(np.int16))
# Out:
# 45
# 7
# <style  type="text/css" >
# </style><table id="T_7223c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Age Bins</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7223c_level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_7223c_row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_7223c_row0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_7223c_level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_7223c_row1_col0" class="data row1 col0" >22</td>
# ...

# %%
#Purchasing Analysis (Age)
 
#Bin the purchase_data data frame by age
age_summary1_df = purchase_data_renamed_df.groupby("Age Bins")
age_summary1_df.head()

#Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#total purchases
total_purchase_age = purchase_data_renamed_df.groupby("Age Bins")["Purchase_Id"].count()
print(total_purchase_age)

#avg purchase price
average_price_age = purchase_data_renamed_df.groupby("Age Bins")["Price"].mean()
print(average_price_age)

#avg purchase total per person
avg_purchase_total_age = age_summary1_df["Price"].sum()
print(avg_purchase_total_age)

#Average Total Purchase by Person by gender
avg_total_purchase_person_age = avg_purchase_total_age/total_age_count
print(avg_total_purchase_person_age)

#Create a summary data frame to hold the results
age_summary1_df = pd.DataFrame({"Purchase Count": total_purchase_age,
                                      "Average Purchase Price": average_price_age,
                                      "Total Purchase Value": avg_purchase_total_age,
                                      "Average Total Purchase per Person": avg_total_purchase_person_age})
age_summary1_df

#Optional: give the displayed data cleaner formatting
age_summary1_df["Average Purchase Price"] = age_summary1_df["Average Purchase Price"].astype(float).map("${:,.2f}".format)
age_summary1_df["Total Purchase Value"] = age_summary1_df["Total Purchase Value"].astype(float).map("${:,.2f}".format)
age_summary1_df["Average Total Purchase per Person"] = age_summary1_df["Average Total Purchase per Person"].astype(float).map("${:,.2f}".format)
#age_summary1_df.style.format({"Average Purchase Price":"${:.2f}"})
#age_summary1_df.style.format({"Total Purchase Value":"${:.2f}"})
#age_summary1_df.style.format({"Average Total Purchase per Person":"${:.2f}"})

#Display the summary data frame
age_summary1_df
# Out:
# Age Bins
# <10       23
# 10-14     28
# 15-19    136
# 20-24    365
# 25-29    101
# 30-34     73
# 35-39     41
# 40+       13
# Name: Purchase_Id, dtype: int64
# Age Bins
# <10      3.353478
# 10-14    2.956429
# 15-19    3.035956
# 20-24    3.052219
# 25-29    2.900990
# 30-34    2.931507
# 35-39    3.601707
# 40+      2.941538
# Name: Price, dtype: float64
# Age Bins
# <10        77.13
# 10-14      82.78
# 15-19     412.89
# 20-24    1114.06
# 25-29     293.00
# 30-34     214.00
# 35-39     147.67
# 40+        38.24
# Name: Price, dtype: float64
# Age Bins
# <10      4.537059
# 10-14    3.762727
# 15-19    3.858785
# 20-24    4.318062
# 25-29    3.805195
# 30-34    4.115385
# 35-39    4.763548
# 40+      3.186667
# dtype: float64
#           Purchase Count Average Purchase Price Total Purchase Value  \
# Age Bins
# <10                   23                  $3.35               $77.13
# 10-14                 28                  $2.96               $82.78
# ...

# %%
#Top Spenders
spender_summary = purchase_data_renamed_df.groupby("SN")
 
#Run basic calculations to obtain the results in the table below - purchase count, purchase price, total purchase value
#total purchases
total_purchase_spender = purchase_data_renamed_df.groupby("SN")["Purchase_Id"].count()
print(total_purchase_spender)

#avg purchase price
average_price_spender = spender_summary["Price"].mean()
print(average_price_spender)

#avg purchase total per person
avg_purchase_total_spender = spender_summary["Price"].sum()
print(avg_purchase_total_spender)

#Create a summary data frame to hold the results
spender_summary1_df = pd.DataFrame({"Purchase Count": total_purchase_spender,
                                      "Average Purchase Price": average_price_spender,
                                      "Total Purchase Value": avg_purchase_total_spender,
                                      })
spender_summary1_df

#Sort the total purchase value column in descending order
spender_summary2_df = spender_summary1_df.sort_values(["Total Purchase Value"], ascending=False).head()
spender_summary2_df

#Optional: give the displayed data cleaner formatting
spender_summary2_df["Average Purchase Price"] = spender_summary2_df["Average Purchase Price"].astype(float).map("${:,.2f}".format)
spender_summary2_df["Total Purchase Value"] = spender_summary2_df["Total Purchase Value"].astype(float).map("${:,.2f}".format)

#Display a preview of the summary data frame
spender_summary2_df
# Out:
# SN
# Adairialis76     1
# Adastirin33      1
# Aeda94           1
# Aela59           1
# Aelaria33        1
#                 ..
# Yathecal82       3
# Yathedeu43       2
# Yoishirrala98    1
# Zhisrisu83       2
# Zontibe81        3
# Name: Purchase_Id, Length: 576, dtype: int64
# SN
# Adairialis76     2.280000
# Adastirin33      4.480000
# Aeda94           4.910000
# Aela59           4.320000
# Aelaria33        1.790000
#                    ...
# Yathecal82       2.073333
# Yathedeu43       3.010000
# Yoishirrala98    4.580000
# Zhisrisu83       3.945000
# Zontibe81        2.676667
# Name: Price, Length: 576, dtype: float64
# SN
# Adairialis76     2.28
# Adastirin33      4.48
# Aeda94           4.91
# Aela59           4.32
# Aelaria33        1.79
#                  ...
# Yathecal82       6.22
# Yathedeu43       6.02
# Yoishirrala98    4.58
# Zhisrisu83       7.89
# Zontibe81        8.03
# Name: Price, Length: 576, dtype: float64
# ...

# %%
#Most Popular Items

#Retrieve the Item ID, Item Name, and Item Price columns
popular_summary = purchase_data_renamed_df[["Item_Id", "Item Name", "Price",
                                           ]]
popular_summary.head()

#Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
popular_summary1 = popular_summary.groupby(["Item_Id","Item Name"])

total_purchase_popular = popular_summary1["Price"].count()
print(total_purchase_popular)

#avg purchase price
average_price_popular = popular_summary1["Price"].mean()
print(average_price_popular)

#avg purchase total per person
avg_purchase_total_popular = popular_summary1["Price"].sum()
print(avg_purchase_total_popular)

#Create a summary data frame to hold the results
popular_summary2_df = pd.DataFrame({"Purchase Count": total_purchase_popular,
                                      "Average Purchase Price": average_price_popular,
                                      "Total Purchase Value": avg_purchase_total_popular,
                                      })
popular_summary2_df

#Sort the purchase count column in descending order
popular_summary3_df = popular_summary2_df.sort_values(["Purchase Count"], ascending=False).head()
popular_summary3_df

#Optional: give the displayed data cleaner formatting
popular_summary3_df["Average Purchase Price"] = popular_summary3_df["Average Purchase Price"].astype(float).map("${:,.2f}".format)
popular_summary3_df["Total Purchase Value"] = popular_summary3_df["Total Purchase Value"].astype(float).map("${:,.2f}".format)

#Display a preview of the summary data frame
popular_summary3_df
# Out:
# Item_Id  Item Name
# 0        Splinter                                         4
# 1        Crucifer                                         4
# 2        Verdict                                          6
# 3        Phantomlight                                     6
# 4        Bloodlord's Fetish                               5
#                                                          ..
# 178      Oathbreaker, Last Hope of the Breaking Storm    12
# 179      Wolf, Promise of the Moonwalker                  6
# 181      Reaper's Toll                                    5
# 182      Toothpick                                        3
# 183      Dragon's Greatsword                              3
# Name: Price, Length: 179, dtype: int64
# Item_Id  Item Name
# 0        Splinter                                        1.2800
# 1        Crucifer                                        2.9425
# 2        Verdict                                         2.4800
# ...

# %%
#Sort the above table by total purchase value in descending order
popular_summary4_df = popular_summary2_df.sort_values(["Total Purchase Value"], ascending=False).head()
popular_summary4_df
#Optional: give the displayed data cleaner formatting
#popular_summary4_df["Average Purchase Price"] = popular_summary4_df["Average Purchase Price"].astype(float).map("${:,.2f}".format)
#popular_summary4_df["Total Purchase Value"] = popular_summary4_df["Total Purchase Value"].astype(float).map("${:,.2f}".format)
popular_summary4_df.style.format({"Average Purchase Price":"${:.2f}"})
popular_summary4_df.style.format({"Total Purchase Value":"${:.2f}"})
#Display a preview of the data frame
popular_summary4_df
# Out:
#                                                       Purchase Count  \
# Item_Id Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                       Average Purchase Price  \
# Item_Id Item Name
# 92      Final Critic                                                4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm                4.230000
# 82      Nirvana                                                     4.900000
# 145     Fiery Glass Crusader                                        4.580000
# 103     Singed Scalpel                                              4.350000
#
# ...
